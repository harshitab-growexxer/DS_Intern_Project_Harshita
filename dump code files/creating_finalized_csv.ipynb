# %%
import pandas as pd

# Column headers
column_headers = [
    'engine', 'cycles', 'alt', 'mach', 'TRA', 'T2', 'T24', 'T30', 'T50', 'P2', 'P15', 'P30',
    'Nf', 'Nc', 'epr', 'Ps30', 'phi', 'NRf', 'NRc', 'BPR', 'farB', 'htBleed', 'Nf_dmd', 'PCNfR_dmd',
    'W31', 'W32', 'source'
]

# Read the CSVs
train_df = pd.read_csv('/content/drive/MyDrive/turbofan dataset/train_FD002.txt', sep=' ', header=None)
test_df = pd.read_csv('/content/drive/MyDrive/turbofan dataset/test_FD002.txt', sep=' ', header=None)

train_df.drop(columns=[26, 27], inplace=True)
test_df.drop(columns=[26, 27], inplace=True)

# Add column headers
train_df.columns = column_headers[:-1]
test_df.columns = column_headers[:-1]

# Add the source column
train_df['source'] = 0
test_df['source'] = 1

# Concatenate the DataFrames
combined_df = pd.concat([train_df, test_df], ignore_index=True)

# Save the combined DataFrame to a new CSV
combined_df.to_csv('combined.csv', index=False)

print("Combined CSV created successfully.")
# Out:
# Combined CSV created successfully.

# %%
combined_df.head()
# Out:
#    engine  cycles      alt    mach    TRA      T2     T24      T30      T50  \
# 0       1       1  34.9983  0.8400  100.0  449.44  555.32  1358.61  1137.23
# 1       1       2  41.9982  0.8408  100.0  445.00  549.90  1353.22  1125.78
# 2       1       3  24.9988  0.6218   60.0  462.54  537.31  1256.76  1047.45
# 3       1       4  42.0077  0.8416  100.0  445.00  549.51  1354.03  1126.38
# 4       1       5  25.0005  0.6203   60.0  462.54  537.07  1257.71  1047.93
#
#      P2  ...      NRf      NRc      BPR  farB  htBleed  Nf_dmd  PCNfR_dmd  \
# 0  5.48  ...  2387.72  8048.56   9.3461  0.02      334    2223     100.00
# 1  3.91  ...  2387.66  8072.30   9.3774  0.02      330    2212     100.00
# 2  7.05  ...  2028.03  7864.87  10.8941  0.02      309    1915      84.93
# 3  3.91  ...  2387.61  8068.66   9.3528  0.02      329    2212     100.00
# 4  7.05  ...  2028.00  7861.23  10.8963  0.02      309    1915      84.93
#
#      W31     W32  source
# 0  14.73  8.8071       0
# ...

# %%
combined_df.shape
# Out:
# (87750, 27)

# %%
combined_df.insert(0, 'index', range(1, len(combined_df) + 1))

# %%
x = combined_df

# %%
x.head()
# Out:
#    index  engine  cycles      alt    mach    TRA      T2     T24      T30  \
# 0      1       1       1  34.9983  0.8400  100.0  449.44  555.32  1358.61
# 1      2       1       2  41.9982  0.8408  100.0  445.00  549.90  1353.22
# 2      3       1       3  24.9988  0.6218   60.0  462.54  537.31  1256.76
# 3      4       1       4  42.0077  0.8416  100.0  445.00  549.51  1354.03
# 4      5       1       5  25.0005  0.6203   60.0  462.54  537.07  1257.71
#
#        T50  ...      NRf      NRc      BPR  farB  htBleed  Nf_dmd  PCNfR_dmd  \
# 0  1137.23  ...  2387.72  8048.56   9.3461  0.02      334    2223     100.00
# 1  1125.78  ...  2387.66  8072.30   9.3774  0.02      330    2212     100.00
# 2  1047.45  ...  2028.03  7864.87  10.8941  0.02      309    1915      84.93
# 3  1126.38  ...  2387.61  8068.66   9.3528  0.02      329    2212     100.00
# 4  1047.93  ...  2028.00  7861.23  10.8963  0.02      309    1915      84.93
#
#      W31     W32  source
# 0  14.73  8.8071       0
# ...

# %%
max(x['index'])
# Out:
# 87750

# %%
x.to_csv('final_data.csv', sep=',', index=False)

# %%
x.describe().T
# Out:
#              count          mean           std        min          25%  \
# index      87750.0  43875.500000  25331.387398     1.0000  21938.25000
# engine     87750.0    129.706051     74.360146     1.0000     66.00000
# cycles     87750.0     98.335305     66.788208     1.0000     43.00000
# alt        87750.0     23.989409     14.759538     0.0000     10.00460
# mach       87750.0      0.571707      0.310395     0.0000      0.25060
# TRA        87750.0     94.054017     14.229790    60.0000    100.00000
# T2         87750.0    472.917893     26.414747   445.0000    445.00000
# T24        87750.0    579.641141     37.308401   535.4100    549.54000
# T30        87750.0   1419.425250    105.960678  1243.7300   1352.31000
# T50        87750.0   1204.529599    119.095741  1023.7700   1123.17000
# P2         87750.0      8.034708      3.617694     3.9100      3.91000
# P15        87750.0     11.604843      5.437617     5.7100      5.72000
# ...

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 87750 entries, 0 to 87749
# Data columns (total 28 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   index      87750 non-null  int64
#  1   engine     87750 non-null  int64
#  2   cycles     87750 non-null  int64
#  3   alt        87750 non-null  float64
#  4   mach       87750 non-null  float64
#  5   TRA        87750 non-null  float64
#  6   T2         87750 non-null  float64
#  7   T24        87750 non-null  float64
#  8   T30        87750 non-null  float64
#  9   T50        87750 non-null  float64
#  10  P2         87750 non-null  float64
#  11  P15        87750 non-null  float64
#  12  P30        87750 non-null  float64
#  13  Nf         87750 non-null  float64
#  14  Nc         87750 non-null  float64
#  15  epr        87750 non-null  float64
#  16  Ps30       87750 non-null  float64
#  17  phi        87750 non-null  float64
#  18  NRf        87750 non-null  float64
# ...
